# %%
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %%
import torch
import torchvision

# %%
# %load_ext autoreload
# %autoreload 2
from dc_bit.data_loader import create_data_loader, LoaderParams, from_pytorch

# %%
path_to_data = Path("/mnt/ml-team/homes/grzegorz.los/datasets/birds")

# %%
params = LoaderParams(
    path_to_data=path_to_data / 'train',
    batch_size=4,
    n_workers=4,
    shuffle=True,
    augment=True
)

# %%
data_loader = create_data_loader(params)
# Out:
# _build_augmentations

# %%
data_loader.dataset.classes
# Out:
# ['crow', 'jackdaw', 'raven', 'rook']

# %%
for el in data_loader:
    print(type(el))
    break
# Out:
# <class 'list'>

# %%
len(el)
# Out:
# 2

# %%
type(el[0])
# Out:
# torch.Tensor

# %%
el[0].shape
# Out:
# torch.Size([4, 3, 224, 224])

# %%
el[1]
# Out:
# tensor([1, 1, 0, 1])

# %%
def display_image(img, label):
    print(label)
    plt.figure(figsize=(5, 5))
    plt.imshow(img)
    plt.show()

def iterate_data_loader(n_elem=1):
    count = 0
    for batch in data_loader:
        imgs, codes = batch
        for img, code in zip(imgs, codes):
            label = data_loader.dataset.classes[code]
            img = from_pytorch(img)
            display_image(img, label)
            count += 1
            if count >= n_elem:
                return

# %%
iterate_data_loader(5)
# Out:
# crow
# rook
# raven
# rook
# crow
